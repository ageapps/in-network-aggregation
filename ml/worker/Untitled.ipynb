# %%
from LinearRegressor import LinearRegressionUsingGD
import numpy as np

# %%
X = 2 * np.random.rand(100, 1)
Y = 4*X + np.random.randn(100, 1)

# %%
eta = 0.1
iterations = 100
model = LinearRegressionUsingGD(eta=eta, n_iterations=iterations)
print("Shape of input: ", X.shape)
print("Shape of output: ", Y.shape)
print("Iterations: ", iterations)
# Out:
# Shape of input:  (100, 1)
# Shape of output:  (100, 1)
# Iterations:  100

# %%
model.fit(X, Y)
model.plotCostAndData()
# Out:
# Number of samples: 100
# Number of features: 1
# Number of out classes: 1
# Epochs: 100
# W: (2, 1)
# X: (100, 1)
# Iter: 0 Cost:14.3452572752523
# Iter: 10 Cost:1.045490423597406
# Iter: 20 Cost:0.841775450440158
# Iter: 30 Cost:0.7371505859466619
# Iter: 40 Cost:0.6596051076623151
# Iter: 50 Cost:0.6019636347674043
# Iter: 60 Cost:0.5591164939497621
# Iter: 70 Cost:0.5272665496459595
# Iter: 80 Cost:0.5035912487132473
# Iter: 90 Cost:0.48599247777315313
# Ploting
